# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('working-dataset.csv')

# %%
data
# Out:
#                                   Material  \
# 0                 Nickel-Based Superalloys
# 1                          Stainless Steel
# 2                          Titanium Alloys
# 3  Carbon Fiber Reinforced Polymers (CFRP)
# 4         Ceramic Matrix Composites (CMCs)
# 5                                  Inconel
# 6                    Single Crystal Alloys
#
#   Approx. Cost per Square Meter (USD) Durability (Months)  Weight (kg/mÂ²)  \
# 0                                $750            10 years              300
# 1                                $200             8 years              200
# 2                               $1050            12 years              150
# 3                                $800             5 years               50
# 4                               $1350            12 years               50
# 5                                $700            15 years              200
# 6                               $1100            13 years              200
#
#   Corrosion Resistance  Temperature Resistance (Â°C) Manufacturing Complexity  \
# 0            Very High                          1000                   Medium
# 1                 High                           250                   Medium
# 2            Very High                          1100                     High
# 3            Very High                           300                   Medium
# 4            Very High                          1050                     High
# 5            Very High                           800                   Medium
# 6            Very High                          1100                     High
#
#   Availability
# 0    Very High
# 1         High
# 2       Medium
# 3       Medium
# 4          Low
# 5    Very High
# 6          Low

# %%
df = data.copy()

# %%
values_tomap = {
    'Very High':5,
    'High' :4,
    'Medium':3,
    'Low':2,
    'Very Low':1
}

# %%
# Use only if the columns name are irreggular
def regularization():
    for col in data.columns:
        data.rename(columns = {col : col.strip()},inplace=True)

# %%
#regularization()

# %%
# mapping five scale values
def mapping_five_scales(columns):
    for col in columns:
        data[col] = data[col].apply(lambda x:x.strip()).map(values_tomap)
    return data

# %%
mapping_five_scales(['Corrosion Resistance','Manufacturing Complexity','Availability'])
# Out:
#                                   Material  \
# 0                 Nickel-Based Superalloys
# 1                          Stainless Steel
# 2                          Titanium Alloys
# 3  Carbon Fiber Reinforced Polymers (CFRP)
# 4         Ceramic Matrix Composites (CMCs)
# 5                                  Inconel
# 6                    Single Crystal Alloys
#
#   Approx. Cost per Square Meter (USD) Durability (Months)  Weight (kg/mÂ²)  \
# 0                                $750            10 years              300
# 1                                $200             8 years              200
# 2                               $1050            12 years              150
# 3                                $800             5 years               50
# 4                               $1350            12 years               50
# 5                                $700            15 years              200
# 6                               $1100            13 years              200
#
#    Corrosion Resistance  Temperature Resistance (Â°C)  \
# 0                     5                          1000
# 1                     4                           250
# 2                     5                          1100
# 3                     5                           300
# 4                     5                          1050
# 5                     5                           800
# 6                     5                          1100
#
#    Manufacturing Complexity  Availability
# 0                         3             5
# 1                         3             4
# 2                         4             3
# 3                         3             3
# 4                         4             2
# 5                         3             5
# 6                         4             2

# %%
data.columns
# Out:
# Index(['Material', 'Approx. Cost per Square Meter (USD)',
#        'Durability (Months)', 'Weight (kg/mÂ²)', 'Corrosion Resistance',
#        'Temperature Resistance (Â°C)', 'Manufacturing Complexity',
#        'Availability'],
#       dtype='object')

# %%
# mapping the integer values
data['Approx. Cost per Square Meter (USD)']   = round(data['Approx. Cost per Square Meter (USD)'].str.replace('$','').astype('float64'),2)
#data['Output (per sq. meter)'] = round(data['Output (per sq. meter)'].str.replace('W','').astype('float64'),2)
data['Durability (Months)']  = round(data['Durability (Months)'].str.replace('years','').astype('float64'),2)

# %%
data
# Out:
#                                   Material  \
# 0                 Nickel-Based Superalloys
# 1                          Stainless Steel
# 2                          Titanium Alloys
# 3  Carbon Fiber Reinforced Polymers (CFRP)
# 4         Ceramic Matrix Composites (CMCs)
# 5                                  Inconel
# 6                    Single Crystal Alloys
#
#    Approx. Cost per Square Meter (USD)  Durability (Months)  Weight (kg/mÂ²)  \
# 0                                750.0                 10.0              300
# 1                                200.0                  8.0              200
# 2                               1050.0                 12.0              150
# 3                                800.0                  5.0               50
# 4                               1350.0                 12.0               50
# 5                                700.0                 15.0              200
# 6                               1100.0                 13.0              200
#
#    Corrosion Resistance  Temperature Resistance (Â°C)  \
# 0                     5                          1000
# 1                     4                           250
# 2                     5                          1100
# 3                     5                           300
# 4                     5                          1050
# 5                     5                           800
# 6                     5                          1100
#
#    Manufacturing Complexity  Availability
# 0                         3             5
# 1                         3             4
# 2                         4             3
# 3                         3             3
# 4                         4             2
# 5                         3             5
# 6                         4             2

# %%
data.drop(columns=['Material'],inplace=True)

# %%
Beneficial = ['Durability (Months)','Corrosion Resistance','Temperature Resistance (Â°C)','Availability']
Non_Beneficial = ['Approx. Cost per Square Meter (USD)','Weight (kg/mÂ²)','Manufacturing Complexity']

# %% [markdown]
# # Step 1 : Normalization matrix based on the Beneficial and Non_beneficial criteria

# %%
def min_max(df):
    df_n = df.copy()
    l = dict()
    for col in df_n.columns:
        l[col] = (min(df_n[col]),max(df_n[col]))
    return l

# %%
def beneficial_normalization(columns,df,min_max_d):
    df_n = df.copy()
    for col in columns:
        df_n[col] = round((df_n[col] - min_max_d[col][0])/(min_max_d[col][1]-min_max_d[col][0]),3)
    return df_n

# %%
def nonBeneficial_normalization(columns,df,min_max_d):
    df_n = df.copy()
    for col in columns:
        df_n[col] = round((min_max_d[col][1]- df_n[col])/(min_max_d[col][1]-min_max_d[col][0]),3)
    return df_n

# %%
min_max_data = min_max(data)
min_max_data
# Out:
# {'Approx. Cost per Square Meter (USD)': (200.0, 1350.0),
#  'Durability (Months)': (5.0, 15.0),
#  'Weight (kg/mÂ²)': (50, 300),
#  'Corrosion Resistance': (4, 5),
#  'Temperature Resistance (Â°C)': (250, 1100),
#  'Manufacturing Complexity': (3, 4),
#  'Availability': (2, 5)}

# %%
norm_bene = beneficial_normalization(Beneficial,data,min_max_data)
norm_nonbene = nonBeneficial_normalization(Non_Beneficial,norm_bene,min_max_data)

# %%
norm_matrix = norm_nonbene.copy()
norm_matrix
# Out:
#    Approx. Cost per Square Meter (USD)  Durability (Months)  Weight (kg/mÂ²)  \
# 0                                0.522                  0.5              0.0
# 1                                1.000                  0.3              0.4
# 2                                0.261                  0.7              0.6
# 3                                0.478                  0.0              1.0
# 4                                0.000                  0.7              1.0
# 5                                0.565                  1.0              0.4
# 6                                0.217                  0.8              0.4
#
#    Corrosion Resistance  Temperature Resistance (Â°C)  \
# 0                   1.0                         0.882
# 1                   0.0                         0.000
# 2                   1.0                         1.000
# 3                   1.0                         0.059
# 4                   1.0                         0.941
# 5                   1.0                         0.647
# 6                   1.0                         1.000
#
#    Manufacturing Complexity  Availability
# 0                       1.0         1.000
# 1                       1.0         0.667
# 2                       0.0         0.333
# 3                       1.0         0.333
# 4                       0.0         0.000
# 5                       1.0         1.000
# 6                       0.0         0.000

# %% [markdown]
# # Step 2 : Difference of Each Alternatives

# %%
# difference of each alternatives
def difference_mat(df):
    l=[]
    for i in range(0,df.shape[0]):
        for j in range(0,df.shape[0]):
            if i!=j:
                l.append(df.loc[i,]-df.loc[j,])
    df_new = pd.DataFrame(naming())
    df_new = pd.concat([df_new,pd.DataFrame(l)],axis=1)
    #df_new  = pd.DataFrame(l)
    return df_new

# %%
#creating material name columns
def naming():
    l=[]
    for i in range(norm_matrix.shape[0]):
        for j in range(norm_matrix.shape[0]):
            if i!=j:
                l.append(f'Nano - Material{(i,j)}')
    return l

# %%
dif_mat = pd.DataFrame()
dif_mat = difference_mat(norm_matrix)
dif_mat.rename(columns = {0:'Nano-materials'},inplace=True)
dif_mat
# Out:
#            Nano-materials  Approx. Cost per Square Meter (USD)  \
# 0   Nano - Material(0, 1)                               -0.478
# 1   Nano - Material(0, 2)                                0.261
# 2   Nano - Material(0, 3)                                0.044
# 3   Nano - Material(0, 4)                                0.522
# 4   Nano - Material(0, 5)                               -0.043
# 5   Nano - Material(0, 6)                                0.305
# 6   Nano - Material(1, 0)                                0.478
# 7   Nano - Material(1, 2)                                0.739
# 8   Nano - Material(1, 3)                                0.522
# 9   Nano - Material(1, 4)                                1.000
# 10  Nano - Material(1, 5)                                0.435
# 11  Nano - Material(1, 6)                                0.783
# 12  Nano - Material(2, 0)                               -0.261
# 13  Nano - Material(2, 1)                               -0.739
# 14  Nano - Material(2, 3)                               -0.217
# 15  Nano - Material(2, 4)                                0.261
# 16  Nano - Material(2, 5)                               -0.304
# 17  Nano - Material(2, 6)                                0.044
# 18  Nano - Material(3, 0)                               -0.044
# 19  Nano - Material(3, 1)                               -0.522
# 20  Nano - Material(3, 2)                                0.217
# 21  Nano - Material(3, 4)                                0.478
# 22  Nano - Material(3, 5)                               -0.087
# 23  Nano - Material(3, 6)                                0.261
# 24  Nano - Material(4, 0)                               -0.522
# 25  Nano - Material(4, 1)                               -1.000
# 26  Nano - Material(4, 2)                               -0.261
# 27  Nano - Material(4, 3)                               -0.478
# 28  Nano - Material(4, 5)                               -0.565
# 29  Nano - Material(4, 6)                               -0.217
# 30  Nano - Material(5, 0)                                0.043
# 31  Nano - Material(5, 1)                               -0.435
# 32  Nano - Material(5, 2)                                0.304
# 33  Nano - Material(5, 3)                                0.087
# 34  Nano - Material(5, 4)                                0.565
# 35  Nano - Material(5, 6)                                0.348
# 36  Nano - Material(6, 0)                               -0.305
# 37  Nano - Material(6, 1)                               -0.783
# 38  Nano - Material(6, 2)                               -0.044
# 39  Nano - Material(6, 3)                               -0.261
# 40  Nano - Material(6, 4)                                0.217
# 41  Nano - Material(6, 5)                               -0.348
#
#     Durability (Months)  Weight (kg/mÂ²)  Corrosion Resistance  \
# 0                   0.2             -0.4                   1.0
# 1                  -0.2             -0.6                   0.0
# 2                   0.5             -1.0                   0.0
# 3                  -0.2             -1.0                   0.0
# 4                  -0.5             -0.4                   0.0
# 5                  -0.3             -0.4                   0.0
# 6                  -0.2              0.4                  -1.0
# 7                  -0.4             -0.2                  -1.0
# 8                   0.3             -0.6                  -1.0
# 9                  -0.4             -0.6                  -1.0
# 10                 -0.7              0.0                  -1.0
# 11                 -0.5              0.0                  -1.0
# 12                  0.2              0.6                   0.0
# 13                  0.4              0.2                   1.0
# 14                  0.7             -0.4                   0.0
# 15                  0.0             -0.4                   0.0
# 16                 -0.3              0.2                   0.0
# 17                 -0.1              0.2                   0.0
# 18                 -0.5              1.0                   0.0
# 19                 -0.3              0.6                   1.0
# 20                 -0.7              0.4                   0.0
# 21                 -0.7              0.0                   0.0
# 22                 -1.0              0.6                   0.0
# 23                 -0.8              0.6                   0.0
# 24                  0.2              1.0                   0.0
# 25                  0.4              0.6                   1.0
# 26                  0.0              0.4                   0.0
# 27                  0.7              0.0                   0.0
# 28                 -0.3              0.6                   0.0
# 29                 -0.1              0.6                   0.0
# 30                  0.5              0.4                   0.0
# 31                  0.7              0.0                   1.0
# 32                  0.3             -0.2                   0.0
# 33                  1.0             -0.6                   0.0
# 34                  0.3             -0.6                   0.0
# 35                  0.2              0.0                   0.0
# 36                  0.3              0.4                   0.0
# 37                  0.5              0.0                   1.0
# 38                  0.1             -0.2                   0.0
# 39                  0.8             -0.6                   0.0
# 40                  0.1             -0.6                   0.0
# 41                 -0.2              0.0                   0.0
#
#     Temperature Resistance (Â°C)  Manufacturing Complexity  Availability
# 0                          0.882                       0.0         0.333
# 1                         -0.118                       1.0         0.667
# 2                          0.823                       0.0         0.667
# 3                         -0.059                       1.0         1.000
# 4                          0.235                       0.0         0.000
# 5                         -0.118                       1.0         1.000
# 6                         -0.882                       0.0        -0.333
# 7                         -1.000                       1.0         0.334
# 8                         -0.059                       0.0         0.334
# 9                         -0.941                       1.0         0.667
# 10                        -0.647                       0.0        -0.333
# 11                        -1.000                       1.0         0.667
# 12                         0.118                      -1.0        -0.667
# 13                         1.000                      -1.0        -0.334
# 14                         0.941                      -1.0         0.000
# 15                         0.059                       0.0         0.333
# 16                         0.353                      -1.0        -0.667
# 17                         0.000                       0.0         0.333
# 18                        -0.823                       0.0        -0.667
# 19                         0.059                       0.0        -0.334
# 20                        -0.941                       1.0         0.000
# 21                        -0.882                       1.0         0.333
# 22                        -0.588                       0.0        -0.667
# 23                        -0.941                       1.0         0.333
# 24                         0.059                      -1.0        -1.000
# 25                         0.941                      -1.0        -0.667
# 26                        -0.059                       0.0        -0.333
# 27                         0.882                      -1.0        -0.333
# 28                         0.294                      -1.0        -1.000
# 29                        -0.059                       0.0         0.000
# 30                        -0.235                       0.0         0.000
# 31                         0.647                       0.0         0.333
# 32                        -0.353                       1.0         0.667
# 33                         0.588                       0.0         0.667
# 34                        -0.294                       1.0         1.000
# 35                        -0.353                       1.0         1.000
# 36                         0.118                      -1.0        -1.000
# 37                         1.000                      -1.0        -0.667
# 38                         0.000                       0.0        -0.333
# 39                         0.941                      -1.0        -0.333
# 40                         0.059                       0.0         0.000
# 41                         0.353                      -1.0        -1.000

# %% [markdown]
# # Step 3 : Calculating Preference function

# %%
def relu(x):
    if x<0:
        return 0
    return x
def preference_function(df):
    df_n = df.copy()
    for col in df_n.columns:
        if col == 'Nano-materials':
            continue
        df_n[col] = df_n[col].apply(lambda x : relu(x))
    return df_n

# %%
pref_mat = preference_function(dif_mat)
pref_mat
# Out:
#            Nano-materials  Approx. Cost per Square Meter (USD)  \
# 0   Nano - Material(0, 1)                                0.000
# 1   Nano - Material(0, 2)                                0.261
# 2   Nano - Material(0, 3)                                0.044
# 3   Nano - Material(0, 4)                                0.522
# 4   Nano - Material(0, 5)                                0.000
# 5   Nano - Material(0, 6)                                0.305
# 6   Nano - Material(1, 0)                                0.478
# 7   Nano - Material(1, 2)                                0.739
# 8   Nano - Material(1, 3)                                0.522
# 9   Nano - Material(1, 4)                                1.000
# 10  Nano - Material(1, 5)                                0.435
# 11  Nano - Material(1, 6)                                0.783
# 12  Nano - Material(2, 0)                                0.000
# 13  Nano - Material(2, 1)                                0.000
# 14  Nano - Material(2, 3)                                0.000
# 15  Nano - Material(2, 4)                                0.261
# 16  Nano - Material(2, 5)                                0.000
# 17  Nano - Material(2, 6)                                0.044
# 18  Nano - Material(3, 0)                                0.000
# 19  Nano - Material(3, 1)                                0.000
# 20  Nano - Material(3, 2)                                0.217
# 21  Nano - Material(3, 4)                                0.478
# 22  Nano - Material(3, 5)                                0.000
# 23  Nano - Material(3, 6)                                0.261
# 24  Nano - Material(4, 0)                                0.000
# 25  Nano - Material(4, 1)                                0.000
# 26  Nano - Material(4, 2)                                0.000
# 27  Nano - Material(4, 3)                                0.000
# 28  Nano - Material(4, 5)                                0.000
# 29  Nano - Material(4, 6)                                0.000
# 30  Nano - Material(5, 0)                                0.043
# 31  Nano - Material(5, 1)                                0.000
# 32  Nano - Material(5, 2)                                0.304
# 33  Nano - Material(5, 3)                                0.087
# 34  Nano - Material(5, 4)                                0.565
# 35  Nano - Material(5, 6)                                0.348
# 36  Nano - Material(6, 0)                                0.000
# 37  Nano - Material(6, 1)                                0.000
# 38  Nano - Material(6, 2)                                0.000
# 39  Nano - Material(6, 3)                                0.000
# 40  Nano - Material(6, 4)                                0.217
# 41  Nano - Material(6, 5)                                0.000
#
#     Durability (Months)  Weight (kg/mÂ²)  Corrosion Resistance  \
# 0                   0.2              0.0                   1.0
# 1                   0.0              0.0                   0.0
# 2                   0.5              0.0                   0.0
# 3                   0.0              0.0                   0.0
# 4                   0.0              0.0                   0.0
# 5                   0.0              0.0                   0.0
# 6                   0.0              0.4                   0.0
# 7                   0.0              0.0                   0.0
# 8                   0.3              0.0                   0.0
# 9                   0.0              0.0                   0.0
# 10                  0.0              0.0                   0.0
# 11                  0.0              0.0                   0.0
# 12                  0.2              0.6                   0.0
# 13                  0.4              0.2                   1.0
# 14                  0.7              0.0                   0.0
# 15                  0.0              0.0                   0.0
# 16                  0.0              0.2                   0.0
# 17                  0.0              0.2                   0.0
# 18                  0.0              1.0                   0.0
# 19                  0.0              0.6                   1.0
# 20                  0.0              0.4                   0.0
# 21                  0.0              0.0                   0.0
# 22                  0.0              0.6                   0.0
# 23                  0.0              0.6                   0.0
# 24                  0.2              1.0                   0.0
# 25                  0.4              0.6                   1.0
# 26                  0.0              0.4                   0.0
# 27                  0.7              0.0                   0.0
# 28                  0.0              0.6                   0.0
# 29                  0.0              0.6                   0.0
# 30                  0.5              0.4                   0.0
# 31                  0.7              0.0                   1.0
# 32                  0.3              0.0                   0.0
# 33                  1.0              0.0                   0.0
# 34                  0.3              0.0                   0.0
# 35                  0.2              0.0                   0.0
# 36                  0.3              0.4                   0.0
# 37                  0.5              0.0                   1.0
# 38                  0.1              0.0                   0.0
# 39                  0.8              0.0                   0.0
# 40                  0.1              0.0                   0.0
# 41                  0.0              0.0                   0.0
#
#     Temperature Resistance (Â°C)  Manufacturing Complexity  Availability
# 0                          0.882                       0.0         0.333
# 1                          0.000                       1.0         0.667
# 2                          0.823                       0.0         0.667
# 3                          0.000                       1.0         1.000
# 4                          0.235                       0.0         0.000
# 5                          0.000                       1.0         1.000
# 6                          0.000                       0.0         0.000
# 7                          0.000                       1.0         0.334
# 8                          0.000                       0.0         0.334
# 9                          0.000                       1.0         0.667
# 10                         0.000                       0.0         0.000
# 11                         0.000                       1.0         0.667
# 12                         0.118                       0.0         0.000
# 13                         1.000                       0.0         0.000
# 14                         0.941                       0.0         0.000
# 15                         0.059                       0.0         0.333
# 16                         0.353                       0.0         0.000
# 17                         0.000                       0.0         0.333
# 18                         0.000                       0.0         0.000
# 19                         0.059                       0.0         0.000
# 20                         0.000                       1.0         0.000
# 21                         0.000                       1.0         0.333
# 22                         0.000                       0.0         0.000
# 23                         0.000                       1.0         0.333
# 24                         0.059                       0.0         0.000
# 25                         0.941                       0.0         0.000
# 26                         0.000                       0.0         0.000
# 27                         0.882                       0.0         0.000
# 28                         0.294                       0.0         0.000
# 29                         0.000                       0.0         0.000
# 30                         0.000                       0.0         0.000
# 31                         0.647                       0.0         0.333
# 32                         0.000                       1.0         0.667
# 33                         0.588                       0.0         0.667
# 34                         0.000                       1.0         1.000
# 35                         0.000                       1.0         1.000
# 36                         0.118                       0.0         0.000
# 37                         1.000                       0.0         0.000
# 38                         0.000                       0.0         0.000
# 39                         0.941                       0.0         0.000
# 40                         0.059                       0.0         0.000
# 41                         0.353                       0.0         0.000

# %% [markdown]
# # Step 4 : Aggregate Preference Function

# %%
def aggregate_function(df,weights):
    df_n = df.copy()
    i=0
    for col in df.columns:
        if col == 'Nano-materials':
            df_n[col] = df_n[col]
            continue
        df_n[col] = df_n[col]*weights[i]
        i+=1
    return df_n

# %%
AHP_weights = [0.07,0.26, 0.19, 0.17, 0.13, 0.1, 0.08]
aggregate_mat = aggregate_function(pref_mat,AHP_weights)
aggregate_mat
# Out:
#            Nano-materials  Approx. Cost per Square Meter (USD)  \
# 0   Nano - Material(0, 1)                              0.00000
# 1   Nano - Material(0, 2)                              0.01827
# 2   Nano - Material(0, 3)                              0.00308
# 3   Nano - Material(0, 4)                              0.03654
# 4   Nano - Material(0, 5)                              0.00000
# 5   Nano - Material(0, 6)                              0.02135
# 6   Nano - Material(1, 0)                              0.03346
# 7   Nano - Material(1, 2)                              0.05173
# 8   Nano - Material(1, 3)                              0.03654
# 9   Nano - Material(1, 4)                              0.07000
# 10  Nano - Material(1, 5)                              0.03045
# 11  Nano - Material(1, 6)                              0.05481
# 12  Nano - Material(2, 0)                              0.00000
# 13  Nano - Material(2, 1)                              0.00000
# 14  Nano - Material(2, 3)                              0.00000
# 15  Nano - Material(2, 4)                              0.01827
# 16  Nano - Material(2, 5)                              0.00000
# 17  Nano - Material(2, 6)                              0.00308
# 18  Nano - Material(3, 0)                              0.00000
# 19  Nano - Material(3, 1)                              0.00000
# 20  Nano - Material(3, 2)                              0.01519
# 21  Nano - Material(3, 4)                              0.03346
# 22  Nano - Material(3, 5)                              0.00000
# 23  Nano - Material(3, 6)                              0.01827
# 24  Nano - Material(4, 0)                              0.00000
# 25  Nano - Material(4, 1)                              0.00000
# 26  Nano - Material(4, 2)                              0.00000
# 27  Nano - Material(4, 3)                              0.00000
# 28  Nano - Material(4, 5)                              0.00000
# 29  Nano - Material(4, 6)                              0.00000
# 30  Nano - Material(5, 0)                              0.00301
# 31  Nano - Material(5, 1)                              0.00000
# 32  Nano - Material(5, 2)                              0.02128
# 33  Nano - Material(5, 3)                              0.00609
# 34  Nano - Material(5, 4)                              0.03955
# 35  Nano - Material(5, 6)                              0.02436
# 36  Nano - Material(6, 0)                              0.00000
# 37  Nano - Material(6, 1)                              0.00000
# 38  Nano - Material(6, 2)                              0.00000
# 39  Nano - Material(6, 3)                              0.00000
# 40  Nano - Material(6, 4)                              0.01519
# 41  Nano - Material(6, 5)                              0.00000
#
#     Durability (Months)  Weight (kg/mÂ²)  Corrosion Resistance  \
# 0                 0.052            0.000                  0.17
# 1                 0.000            0.000                  0.00
# 2                 0.130            0.000                  0.00
# 3                 0.000            0.000                  0.00
# 4                 0.000            0.000                  0.00
# 5                 0.000            0.000                  0.00
# 6                 0.000            0.076                  0.00
# 7                 0.000            0.000                  0.00
# 8                 0.078            0.000                  0.00
# 9                 0.000            0.000                  0.00
# 10                0.000            0.000                  0.00
# 11                0.000            0.000                  0.00
# 12                0.052            0.114                  0.00
# 13                0.104            0.038                  0.17
# 14                0.182            0.000                  0.00
# 15                0.000            0.000                  0.00
# 16                0.000            0.038                  0.00
# 17                0.000            0.038                  0.00
# 18                0.000            0.190                  0.00
# 19                0.000            0.114                  0.17
# 20                0.000            0.076                  0.00
# 21                0.000            0.000                  0.00
# 22                0.000            0.114                  0.00
# 23                0.000            0.114                  0.00
# 24                0.052            0.190                  0.00
# 25                0.104            0.114                  0.17
# 26                0.000            0.076                  0.00
# 27                0.182            0.000                  0.00
# 28                0.000            0.114                  0.00
# 29                0.000            0.114                  0.00
# 30                0.130            0.076                  0.00
# 31                0.182            0.000                  0.17
# 32                0.078            0.000                  0.00
# 33                0.260            0.000                  0.00
# 34                0.078            0.000                  0.00
# 35                0.052            0.000                  0.00
# 36                0.078            0.076                  0.00
# 37                0.130            0.000                  0.17
# 38                0.026            0.000                  0.00
# 39                0.208            0.000                  0.00
# 40                0.026            0.000                  0.00
# 41                0.000            0.000                  0.00
#
#     Temperature Resistance (Â°C)  Manufacturing Complexity  Availability
# 0                        0.11466                       0.0       0.02664
# 1                        0.00000                       0.1       0.05336
# 2                        0.10699                       0.0       0.05336
# 3                        0.00000                       0.1       0.08000
# 4                        0.03055                       0.0       0.00000
# 5                        0.00000                       0.1       0.08000
# 6                        0.00000                       0.0       0.00000
# 7                        0.00000                       0.1       0.02672
# 8                        0.00000                       0.0       0.02672
# 9                        0.00000                       0.1       0.05336
# 10                       0.00000                       0.0       0.00000
# 11                       0.00000                       0.1       0.05336
# 12                       0.01534                       0.0       0.00000
# 13                       0.13000                       0.0       0.00000
# 14                       0.12233                       0.0       0.00000
# 15                       0.00767                       0.0       0.02664
# 16                       0.04589                       0.0       0.00000
# 17                       0.00000                       0.0       0.02664
# 18                       0.00000                       0.0       0.00000
# 19                       0.00767                       0.0       0.00000
# 20                       0.00000                       0.1       0.00000
# 21                       0.00000                       0.1       0.02664
# 22                       0.00000                       0.0       0.00000
# 23                       0.00000                       0.1       0.02664
# 24                       0.00767                       0.0       0.00000
# 25                       0.12233                       0.0       0.00000
# 26                       0.00000                       0.0       0.00000
# 27                       0.11466                       0.0       0.00000
# 28                       0.03822                       0.0       0.00000
# 29                       0.00000                       0.0       0.00000
# 30                       0.00000                       0.0       0.00000
# 31                       0.08411                       0.0       0.02664
# 32                       0.00000                       0.1       0.05336
# 33                       0.07644                       0.0       0.05336
# 34                       0.00000                       0.1       0.08000
# 35                       0.00000                       0.1       0.08000
# 36                       0.01534                       0.0       0.00000
# 37                       0.13000                       0.0       0.00000
# 38                       0.00000                       0.0       0.00000
# 39                       0.12233                       0.0       0.00000
# 40                       0.00767                       0.0       0.00000
# 41                       0.04589                       0.0       0.00000

# %%
def sum_of_rows(df):
    l=[]
    df_n = df.copy()
    for i in range(df_n.shape[0]):
        l.append(sum(df_n.loc[i,]))
    df_n['Weighted'] = l
    return df_n

# %%
weighted_mat = aggregate_mat.copy()
weighted_mat = sum_of_rows(aggregate_mat.iloc[:,1:])

# %%
list_ = weighted_mat['Weighted']

# %% [markdown]
# # Step 4 : Forming Aggregated Matrix

# %%
def new_agg_mat_fun(df,list_,n):
    k=0
    new_agg_mat = df.copy()
    for i in range(n+1):
        for j in range(n+1):
            if i !=j:
                new_agg_mat.iloc[i,j] = list_[k]
                k+=1;
            else:
                new_agg_mat.iloc[i,j] = 0
    return new_agg_mat

# %%
new_agg_mat = new_agg_mat_fun(norm_matrix,list_,6)
new_agg_mat
# Out:
#    Approx. Cost per Square Meter (USD)  Durability (Months)  Weight (kg/mÂ²)  \
# 0                              0.00000              0.36330          0.17163
# 1                              0.10946              0.00000          0.17845
# 2                              0.18134              0.44200          0.00000
# 3                              0.19000              0.29167          0.19119
# 4                              0.24967              0.51033          0.07600
# 5                              0.20901              0.46275          0.25264
# 6                              0.16934              0.43000          0.02600
#
#    Corrosion Resistance  Temperature Resistance (Â°C)  \
# 0               0.29343                       0.21654
# 1               0.14126                       0.22336
# 2               0.30433                       0.05258
# 3               0.00000                       0.16010
# 4               0.29666                       0.00000
# 5               0.39589                       0.29755
# 6               0.33033                       0.04886
#
#    Manufacturing Complexity  Availability
# 0                   0.03055       0.20135
# 1                   0.03045       0.20817
# 2                   0.08389       0.06772
# 3                   0.11400       0.25891
# 4                   0.15222       0.11400
# 5                   0.00000       0.25636
# 6                   0.04589       0.00000

# %% [markdown]
# # Step 5 : calculating leaving and entering variables

# %%
def leaving_flow(df):
    df_n = df.copy()
    l=[]
    for i in range(df.shape[0]):
        l.append(round(sum(df_n.loc[i,])/len(df_n.loc[i,]),4))
    return l

# %%
def entering_flow(df):
    df_n = df.copy()
    l=[]
    for col in df_n.columns:
        l.append(round(sum(df[col])/df_n.shape[0],4))
    return l

# %%
def outrank():
    out_rank_df   = pd.DataFrame()
    out_rank_df['leaving_flow'] =  leaving_flow(new_agg_mat)
    out_rank_df['entering_flow'] = entering_flow(new_agg_mat)
    return out_rank_df

# %%
rank_mat = outrank()
rank_mat['Difference'] = rank_mat['leaving_flow']-rank_mat['entering_flow']

# %%
for col in df.columns:
    df.rename(columns = {col:col.strip()},inplace=True)

# %%
rank_mat['ranks'] = rank_mat['Difference'].rank(ascending=False).astype(int)
rank_mat['Material'] = df['Material']

# %%
# reordering
rank_mat = rank_mat[['Material','leaving_flow','entering_flow','Difference','ranks']]
rank_mat
# Out:
#                                   Material  leaving_flow  entering_flow  \
# 0                 Nickel-Based Superalloys        0.1824         0.1584
# 1                          Stainless Steel        0.1273         0.3572
# 2                          Titanium Alloys        0.1617         0.1280
# 3  Carbon Fiber Reinforced Polymers (CFRP)        0.1723         0.2517
# 4         Ceramic Matrix Composites (CMCs)        0.1998         0.1427
# 5                                  Inconel        0.2677         0.0653
# 6                    Single Crystal Alloys        0.1501         0.1581
#
#    Difference  ranks
# 0      0.0240      4
# 1     -0.2299      7
# 2      0.0337      3
# 3     -0.0794      6
# 4      0.0571      2
# 5      0.2024      1
# 6     -0.0080      5

# %% [markdown]
# # Promethee 1

# %%
def leaving_flow_pr1(df):
    df_n = df.copy()
    l=[]
    for i in range(df.shape[0]):
        l.append(round(sum(df_n.loc[i,]),4))
    return l

# %%
def entering_flow_pr1(df):
    df_n = df.copy()
    l=[]
    for col in df_n.columns:
        l.append(round(sum(df[col]),4))
    return l

# %%
def outrank_pr1():
    out_rank_df   = pd.DataFrame()
    out_rank_df['leaving_flow'] =  leaving_flow_pr1(new_agg_mat)
    out_rank_df['entering_flow'] = entering_flow_pr1(new_agg_mat)
    return out_rank_df

# %%
rank_mat_pr1 = outrank_pr1()

# %%
rank_mat_pr1
# Out:
#    leaving_flow  entering_flow
# 0        1.2768         1.1088
# 1        0.8912         2.5001
# 2        1.1319         0.8959
# 3        1.2059         1.7619
# 4        1.3989         0.9990
# 5        1.8742         0.4570
# 6        1.0504         1.1065

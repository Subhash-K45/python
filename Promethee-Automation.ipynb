# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('nano-particle-road exact.csv')

# %%
data
# Out:
#     Material                  Output (per sq. meter)      \
# 0   Piezoelectric             0.05 W
# 1   Triboelectric                0.01 W
# 2   Thermoelectric            0.55 W
# 3   Photovoltaic              105 W
# 4   Electroactive Polymers    0.05 W
# 5   Magnetoelectric           0.05 W
# 6   Pyroelectric              0.05 W
#
#     Cost (per sq. meter)    Durability    Efficiency    Sensitivity   \
# 0   $50                     7.5 years     Medium        Low
# 1   $5                      5.5 years     High          High
# 2   $275                    11.5 years    Medium        Medium
# 3   $1.10                   20 years      Medium        Very Low
# 4   $27.50                  3.5 years     Medium        Very Low
# 5   $550                    8.5 years     High          High
# 6   $110                    7.5 years     High          Medium
#
#     Maintenance    Scalability
# 0   Very Low       High
# 1   Low            Very High
# 2   Low            Very High
# 3   High           Medium
# 4   Low            High
# 5   Low            Very High
# 6   Very Low       High

# %%
df = data.copy()

# %%
values_tomap = {
    'Very High':5,
    'High' :4,
    'Medium':3,
    'Low':2,
    'Very Low':1
}

# %%
# Use only if the columns name are irreggular
def regularization():
    for col in data.columns:
        data.rename(columns = {col : col.strip()},inplace=True)

# %%
regularization()

# %%
# mapping five scale values
def mapping_five_scales(columns):
    for col in columns:
        data[col] = data[col].apply(lambda x:x.strip()).map(values_tomap)
    return data

# %%
mapping_five_scales(['Efficiency','Sensitivity','Maintenance','Scalability'])
# Out:
#                    Material       Output (per sq. meter)  \
# 0   Piezoelectric             0.05 W
# 1   Triboelectric                0.01 W
# 2   Thermoelectric            0.55 W
# 3   Photovoltaic              105 W
# 4   Electroactive Polymers    0.05 W
# 5   Magnetoelectric           0.05 W
# 6   Pyroelectric              0.05 W
#
#      Cost (per sq. meter)    Durability  Efficiency  Sensitivity  Maintenance  \
# 0   $50                     7.5 years             3            2            1
# 1   $5                      5.5 years             4            4            2
# 2   $275                    11.5 years            3            3            2
# 3   $1.10                   20 years              3            1            4
# 4   $27.50                  3.5 years             3            1            2
# 5   $550                    8.5 years             4            4            2
# 6   $110                    7.5 years             4            3            1
#
#    Scalability
# 0            4
# 1            5
# 2            5
# 3            3
# 4            4
# 5            5
# 6            4

# %%
# mapping the integer values
data['Cost (per sq. meter)']   = round(data['Cost (per sq. meter)'].str.replace('$','').astype('float64'),2)
data['Output (per sq. meter)'] = round(data['Output (per sq. meter)'].str.replace('W','').astype('float64'),2)
data['Durability']             = round(data['Durability'].str.replace('years','').astype('float64'),2)

# %%
data
# Out:
#                    Material  Output (per sq. meter)  Cost (per sq. meter)  \
# 0   Piezoelectric                              0.05                  50.0
# 1   Triboelectric                              0.01                   5.0
# 2   Thermoelectric                             0.55                 275.0
# 3   Photovoltaic                             105.00                   1.1
# 4   Electroactive Polymers                     0.05                  27.5
# 5   Magnetoelectric                            0.05                 550.0
# 6   Pyroelectric                               0.05                 110.0
#
#    Durability  Efficiency  Sensitivity  Maintenance  Scalability
# 0         7.5           3            2            1            4
# 1         5.5           4            4            2            5
# 2        11.5           3            3            2            5
# 3        20.0           3            1            4            3
# 4         3.5           3            1            2            4
# 5         8.5           4            4            2            5
# 6         7.5           4            3            1            4

# %%
data.drop(columns=['Material'],inplace=True)

# %%
Beneficial = ['Output (per sq. meter)','Durability','Efficiency','Scalability']
Non_Beneficial = ['Cost (per sq. meter)','Sensitivity','Maintenance']

# %% [markdown]
# # Step 1 : Normalization matrix based on the Beneficial and Non_beneficial criteria

# %%
def min_max(df):
    df_n = df.copy()
    l = dict()
    for col in df_n.columns:
        l[col] = (min(df_n[col]),max(df_n[col]))
    return l

# %%
def beneficial_normalization(columns,df,min_max_d):
    df_n = df.copy()
    for col in columns:
        df_n[col] = (df_n[col] - min_max_d[col][0])/(min_max_d[col][1]-min_max_d[col][0])
    return df_n

# %%
def nonBeneficial_normalization(columns,df,min_max_d):
    df_n = df.copy()
    for col in columns:
        df_n[col] = (min_max_d[col][1]- df_n[col])/(min_max_d[col][1]-min_max_d[col][0])
    return df_n

# %%
min_max_data = min_max(data)
min_max_data
# Out:
# {'Output (per sq. meter)': (0.01, 105.0),
#  'Cost (per sq. meter)': (1.1, 550.0),
#  'Durability': (3.5, 20.0),
#  'Efficiency': (3, 4),
#  'Sensitivity': (1, 4),
#  'Maintenance': (1, 4),
#  'Scalability': (3, 5)}

# %%
norm_bene = beneficial_normalization(Beneficial,data,min_max_data)
norm_nonbene = nonBeneficial_normalization(Non_Beneficial,norm_bene,min_max_data)

# %%
norm_matrix = norm_nonbene.copy()
norm_matrix
# Out:
#    Output (per sq. meter)  Cost (per sq. meter)  Durability  Efficiency  \
# 0                0.000381              0.910913    0.242424         0.0
# 1                0.000000              0.992895    0.121212         1.0
# 2                0.005143              0.501002    0.484848         0.0
# 3                1.000000              1.000000    1.000000         0.0
# 4                0.000381              0.951904    0.000000         0.0
# 5                0.000381              0.000000    0.303030         1.0
# 6                0.000381              0.801603    0.242424         1.0
#
#    Sensitivity  Maintenance  Scalability
# 0     0.666667     1.000000          0.5
# 1     0.000000     0.666667          1.0
# 2     0.333333     0.666667          1.0
# 3     1.000000     0.000000          0.0
# 4     1.000000     0.666667          0.5
# 5     0.000000     0.666667          1.0
# 6     0.333333     1.000000          0.5

# %% [markdown]
# # Step 2 : Difference of Each Alternatives

# %%
# difference of each alternatives
def difference_mat(df):
    l=[]
    for i in range(0,df.shape[0]):
        for j in range(0,df.shape[0]):
            if i!=j:
                l.append(df.loc[i,]-df.loc[j,])
    df_new = pd.DataFrame(naming())
    df_new = pd.concat([df_new,pd.DataFrame(l)],axis=1)
    #df_new  = pd.DataFrame(l)
    return df_new

# %%
#creating material name columns
def naming():
    l=[]
    for i in range(norm_matrix.shape[0]):
        for j in range(norm_matrix.shape[0]):
            if i!=j:
                l.append(f'Nano - Material{(i,j)}')
    return l

# %%
dif_mat = pd.DataFrame()
dif_mat = difference_mat(norm_matrix)
dif_mat.rename(columns = {0:'Nano-materials'},inplace=True)
dif_mat
# Out:
#            Nano-materials  Output (per sq. meter)  Cost (per sq. meter)  \
# 0   Nano - Material(0, 1)                0.000381             -0.081982
# 1   Nano - Material(0, 2)               -0.004762              0.409911
# 2   Nano - Material(0, 3)               -0.999619             -0.089087
# 3   Nano - Material(0, 4)                0.000000             -0.040991
# 4   Nano - Material(0, 5)                0.000000              0.910913
# 5   Nano - Material(0, 6)                0.000000              0.109310
# 6   Nano - Material(1, 0)               -0.000381              0.081982
# 7   Nano - Material(1, 2)               -0.005143              0.491893
# 8   Nano - Material(1, 3)               -1.000000             -0.007105
# 9   Nano - Material(1, 4)               -0.000381              0.040991
# 10  Nano - Material(1, 5)               -0.000381              0.992895
# 11  Nano - Material(1, 6)               -0.000381              0.191292
# 12  Nano - Material(2, 0)                0.004762             -0.409911
# 13  Nano - Material(2, 1)                0.005143             -0.491893
# 14  Nano - Material(2, 3)               -0.994857             -0.498998
# 15  Nano - Material(2, 4)                0.004762             -0.450902
# 16  Nano - Material(2, 5)                0.004762              0.501002
# 17  Nano - Material(2, 6)                0.004762             -0.300601
# 18  Nano - Material(3, 0)                0.999619              0.089087
# 19  Nano - Material(3, 1)                1.000000              0.007105
# 20  Nano - Material(3, 2)                0.994857              0.498998
# 21  Nano - Material(3, 4)                0.999619              0.048096
# 22  Nano - Material(3, 5)                0.999619              1.000000
# 23  Nano - Material(3, 6)                0.999619              0.198397
# 24  Nano - Material(4, 0)                0.000000              0.040991
# 25  Nano - Material(4, 1)                0.000381             -0.040991
# 26  Nano - Material(4, 2)               -0.004762              0.450902
# 27  Nano - Material(4, 3)               -0.999619             -0.048096
# 28  Nano - Material(4, 5)                0.000000              0.951904
# 29  Nano - Material(4, 6)                0.000000              0.150301
# 30  Nano - Material(5, 0)                0.000000             -0.910913
# 31  Nano - Material(5, 1)                0.000381             -0.992895
# 32  Nano - Material(5, 2)               -0.004762             -0.501002
# 33  Nano - Material(5, 3)               -0.999619             -1.000000
# 34  Nano - Material(5, 4)                0.000000             -0.951904
# 35  Nano - Material(5, 6)                0.000000             -0.801603
# 36  Nano - Material(6, 0)                0.000000             -0.109310
# 37  Nano - Material(6, 1)                0.000381             -0.191292
# 38  Nano - Material(6, 2)               -0.004762              0.300601
# 39  Nano - Material(6, 3)               -0.999619             -0.198397
# 40  Nano - Material(6, 4)                0.000000             -0.150301
# 41  Nano - Material(6, 5)                0.000000              0.801603
#
#     Durability  Efficiency  Sensitivity  Maintenance  Scalability
# 0     0.121212        -1.0     0.666667     0.333333         -0.5
# 1    -0.242424         0.0     0.333333     0.333333         -0.5
# 2    -0.757576         0.0    -0.333333     1.000000          0.5
# 3     0.242424         0.0    -0.333333     0.333333          0.0
# 4    -0.060606        -1.0     0.666667     0.333333         -0.5
# 5     0.000000        -1.0     0.333333     0.000000          0.0
# 6    -0.121212         1.0    -0.666667    -0.333333          0.5
# 7    -0.363636         1.0    -0.333333     0.000000          0.0
# 8    -0.878788         1.0    -1.000000     0.666667          1.0
# 9     0.121212         1.0    -1.000000     0.000000          0.5
# 10   -0.181818         0.0     0.000000     0.000000          0.0
# 11   -0.121212         0.0    -0.333333    -0.333333          0.5
# 12    0.242424         0.0    -0.333333    -0.333333          0.5
# 13    0.363636        -1.0     0.333333     0.000000          0.0
# 14   -0.515152         0.0    -0.666667     0.666667          1.0
# 15    0.484848         0.0    -0.666667     0.000000          0.5
# 16    0.181818        -1.0     0.333333     0.000000          0.0
# 17    0.242424        -1.0     0.000000    -0.333333          0.5
# 18    0.757576         0.0     0.333333    -1.000000         -0.5
# 19    0.878788        -1.0     1.000000    -0.666667         -1.0
# 20    0.515152         0.0     0.666667    -0.666667         -1.0
# 21    1.000000         0.0     0.000000    -0.666667         -0.5
# 22    0.696970        -1.0     1.000000    -0.666667         -1.0
# 23    0.757576        -1.0     0.666667    -1.000000         -0.5
# 24   -0.242424         0.0     0.333333    -0.333333          0.0
# 25   -0.121212        -1.0     1.000000     0.000000         -0.5
# 26   -0.484848         0.0     0.666667     0.000000         -0.5
# 27   -1.000000         0.0     0.000000     0.666667          0.5
# 28   -0.303030        -1.0     1.000000     0.000000         -0.5
# 29   -0.242424        -1.0     0.666667    -0.333333          0.0
# 30    0.060606         1.0    -0.666667    -0.333333          0.5
# 31    0.181818         0.0     0.000000     0.000000          0.0
# 32   -0.181818         1.0    -0.333333     0.000000          0.0
# 33   -0.696970         1.0    -1.000000     0.666667          1.0
# 34    0.303030         1.0    -1.000000     0.000000          0.5
# 35    0.060606         0.0    -0.333333    -0.333333          0.5
# 36    0.000000         1.0    -0.333333     0.000000          0.0
# 37    0.121212         0.0     0.333333     0.333333         -0.5
# 38   -0.242424         1.0     0.000000     0.333333         -0.5
# 39   -0.757576         1.0    -0.666667     1.000000          0.5
# 40    0.242424         1.0    -0.666667     0.333333          0.0
# 41   -0.060606         0.0     0.333333     0.333333         -0.5

# %% [markdown]
# # Step 3 : Calculating Preference function

# %%
def relu(x):
    if x<0:
        return 0
    return x
def preference_function(df):
    df_n = df.copy()
    for col in df_n.columns:
        if col == 'Nano-materials':
            continue
        df_n[col] = df_n[col].apply(lambda x : relu(x))
    return df_n

# %%
pref_mat = preference_function(dif_mat)
pref_mat
# Out:
#            Nano-materials  Output (per sq. meter)  Cost (per sq. meter)  \
# 0   Nano - Material(0, 1)                0.000381              0.000000
# 1   Nano - Material(0, 2)                0.000000              0.409911
# 2   Nano - Material(0, 3)                0.000000              0.000000
# 3   Nano - Material(0, 4)                0.000000              0.000000
# 4   Nano - Material(0, 5)                0.000000              0.910913
# 5   Nano - Material(0, 6)                0.000000              0.109310
# 6   Nano - Material(1, 0)                0.000000              0.081982
# 7   Nano - Material(1, 2)                0.000000              0.491893
# 8   Nano - Material(1, 3)                0.000000              0.000000
# 9   Nano - Material(1, 4)                0.000000              0.040991
# 10  Nano - Material(1, 5)                0.000000              0.992895
# 11  Nano - Material(1, 6)                0.000000              0.191292
# 12  Nano - Material(2, 0)                0.004762              0.000000
# 13  Nano - Material(2, 1)                0.005143              0.000000
# 14  Nano - Material(2, 3)                0.000000              0.000000
# 15  Nano - Material(2, 4)                0.004762              0.000000
# 16  Nano - Material(2, 5)                0.004762              0.501002
# 17  Nano - Material(2, 6)                0.004762              0.000000
# 18  Nano - Material(3, 0)                0.999619              0.089087
# 19  Nano - Material(3, 1)                1.000000              0.007105
# 20  Nano - Material(3, 2)                0.994857              0.498998
# 21  Nano - Material(3, 4)                0.999619              0.048096
# 22  Nano - Material(3, 5)                0.999619              1.000000
# 23  Nano - Material(3, 6)                0.999619              0.198397
# 24  Nano - Material(4, 0)                0.000000              0.040991
# 25  Nano - Material(4, 1)                0.000381              0.000000
# 26  Nano - Material(4, 2)                0.000000              0.450902
# 27  Nano - Material(4, 3)                0.000000              0.000000
# 28  Nano - Material(4, 5)                0.000000              0.951904
# 29  Nano - Material(4, 6)                0.000000              0.150301
# 30  Nano - Material(5, 0)                0.000000              0.000000
# 31  Nano - Material(5, 1)                0.000381              0.000000
# 32  Nano - Material(5, 2)                0.000000              0.000000
# 33  Nano - Material(5, 3)                0.000000              0.000000
# 34  Nano - Material(5, 4)                0.000000              0.000000
# 35  Nano - Material(5, 6)                0.000000              0.000000
# 36  Nano - Material(6, 0)                0.000000              0.000000
# 37  Nano - Material(6, 1)                0.000381              0.000000
# 38  Nano - Material(6, 2)                0.000000              0.300601
# 39  Nano - Material(6, 3)                0.000000              0.000000
# 40  Nano - Material(6, 4)                0.000000              0.000000
# 41  Nano - Material(6, 5)                0.000000              0.801603
#
#     Durability  Efficiency  Sensitivity  Maintenance  Scalability
# 0     0.121212         0.0     0.666667     0.333333          0.0
# 1     0.000000         0.0     0.333333     0.333333          0.0
# 2     0.000000         0.0     0.000000     1.000000          0.5
# 3     0.242424         0.0     0.000000     0.333333          0.0
# 4     0.000000         0.0     0.666667     0.333333          0.0
# 5     0.000000         0.0     0.333333     0.000000          0.0
# 6     0.000000         1.0     0.000000     0.000000          0.5
# 7     0.000000         1.0     0.000000     0.000000          0.0
# 8     0.000000         1.0     0.000000     0.666667          1.0
# 9     0.121212         1.0     0.000000     0.000000          0.5
# 10    0.000000         0.0     0.000000     0.000000          0.0
# 11    0.000000         0.0     0.000000     0.000000          0.5
# 12    0.242424         0.0     0.000000     0.000000          0.5
# 13    0.363636         0.0     0.333333     0.000000          0.0
# 14    0.000000         0.0     0.000000     0.666667          1.0
# 15    0.484848         0.0     0.000000     0.000000          0.5
# 16    0.181818         0.0     0.333333     0.000000          0.0
# 17    0.242424         0.0     0.000000     0.000000          0.5
# 18    0.757576         0.0     0.333333     0.000000          0.0
# 19    0.878788         0.0     1.000000     0.000000          0.0
# 20    0.515152         0.0     0.666667     0.000000          0.0
# 21    1.000000         0.0     0.000000     0.000000          0.0
# 22    0.696970         0.0     1.000000     0.000000          0.0
# 23    0.757576         0.0     0.666667     0.000000          0.0
# 24    0.000000         0.0     0.333333     0.000000          0.0
# 25    0.000000         0.0     1.000000     0.000000          0.0
# 26    0.000000         0.0     0.666667     0.000000          0.0
# 27    0.000000         0.0     0.000000     0.666667          0.5
# 28    0.000000         0.0     1.000000     0.000000          0.0
# 29    0.000000         0.0     0.666667     0.000000          0.0
# 30    0.060606         1.0     0.000000     0.000000          0.5
# 31    0.181818         0.0     0.000000     0.000000          0.0
# 32    0.000000         1.0     0.000000     0.000000          0.0
# 33    0.000000         1.0     0.000000     0.666667          1.0
# 34    0.303030         1.0     0.000000     0.000000          0.5
# 35    0.060606         0.0     0.000000     0.000000          0.5
# 36    0.000000         1.0     0.000000     0.000000          0.0
# 37    0.121212         0.0     0.333333     0.333333          0.0
# 38    0.000000         1.0     0.000000     0.333333          0.0
# 39    0.000000         1.0     0.000000     1.000000          0.5
# 40    0.242424         1.0     0.000000     0.333333          0.0
# 41    0.000000         0.0     0.333333     0.333333          0.0

# %% [markdown]
# # Step 4 : Aggregate Preference Function

# %%
def aggregate_function(df,weights):
    df_n = df.copy()
    i=0
    for col in df.columns:
        if col == 'Nano-materials':
            df_n[col] = df_n[col]
            continue
        df_n[col] = df_n[col]*weights[i]
        i+=1
    return df_n

# %%
AHP_weights = [0.07,0.26, 0.19, 0.17, 0.13, 0.1, 0.08]
aggregate_mat = aggregate_function(pref_mat,AHP_weights)
aggregate_mat
# Out:
#            Nano-materials  Output (per sq. meter)  Cost (per sq. meter)  \
# 0   Nano - Material(0, 1)                0.000027              0.000000
# 1   Nano - Material(0, 2)                0.000000              0.106577
# 2   Nano - Material(0, 3)                0.000000              0.000000
# 3   Nano - Material(0, 4)                0.000000              0.000000
# 4   Nano - Material(0, 5)                0.000000              0.236837
# 5   Nano - Material(0, 6)                0.000000              0.028420
# 6   Nano - Material(1, 0)                0.000000              0.021315
# 7   Nano - Material(1, 2)                0.000000              0.127892
# 8   Nano - Material(1, 3)                0.000000              0.000000
# 9   Nano - Material(1, 4)                0.000000              0.010658
# 10  Nano - Material(1, 5)                0.000000              0.258153
# 11  Nano - Material(1, 6)                0.000000              0.049736
# 12  Nano - Material(2, 0)                0.000333              0.000000
# 13  Nano - Material(2, 1)                0.000360              0.000000
# 14  Nano - Material(2, 3)                0.000000              0.000000
# 15  Nano - Material(2, 4)                0.000333              0.000000
# 16  Nano - Material(2, 5)                0.000333              0.130261
# 17  Nano - Material(2, 6)                0.000333              0.000000
# 18  Nano - Material(3, 0)                0.069973              0.023163
# 19  Nano - Material(3, 1)                0.070000              0.001847
# 20  Nano - Material(3, 2)                0.069640              0.129739
# 21  Nano - Material(3, 4)                0.069973              0.012505
# 22  Nano - Material(3, 5)                0.069973              0.260000
# 23  Nano - Material(3, 6)                0.069973              0.051583
# 24  Nano - Material(4, 0)                0.000000              0.010658
# 25  Nano - Material(4, 1)                0.000027              0.000000
# 26  Nano - Material(4, 2)                0.000000              0.117234
# 27  Nano - Material(4, 3)                0.000000              0.000000
# 28  Nano - Material(4, 5)                0.000000              0.247495
# 29  Nano - Material(4, 6)                0.000000              0.039078
# 30  Nano - Material(5, 0)                0.000000              0.000000
# 31  Nano - Material(5, 1)                0.000027              0.000000
# 32  Nano - Material(5, 2)                0.000000              0.000000
# 33  Nano - Material(5, 3)                0.000000              0.000000
# 34  Nano - Material(5, 4)                0.000000              0.000000
# 35  Nano - Material(5, 6)                0.000000              0.000000
# 36  Nano - Material(6, 0)                0.000000              0.000000
# 37  Nano - Material(6, 1)                0.000027              0.000000
# 38  Nano - Material(6, 2)                0.000000              0.078156
# 39  Nano - Material(6, 3)                0.000000              0.000000
# 40  Nano - Material(6, 4)                0.000000              0.000000
# 41  Nano - Material(6, 5)                0.000000              0.208417
#
#     Durability  Efficiency  Sensitivity  Maintenance  Scalability
# 0     0.023030        0.00     0.086667     0.033333         0.00
# 1     0.000000        0.00     0.043333     0.033333         0.00
# 2     0.000000        0.00     0.000000     0.100000         0.04
# 3     0.046061        0.00     0.000000     0.033333         0.00
# 4     0.000000        0.00     0.086667     0.033333         0.00
# 5     0.000000        0.00     0.043333     0.000000         0.00
# 6     0.000000        0.17     0.000000     0.000000         0.04
# 7     0.000000        0.17     0.000000     0.000000         0.00
# 8     0.000000        0.17     0.000000     0.066667         0.08
# 9     0.023030        0.17     0.000000     0.000000         0.04
# 10    0.000000        0.00     0.000000     0.000000         0.00
# 11    0.000000        0.00     0.000000     0.000000         0.04
# 12    0.046061        0.00     0.000000     0.000000         0.04
# 13    0.069091        0.00     0.043333     0.000000         0.00
# 14    0.000000        0.00     0.000000     0.066667         0.08
# 15    0.092121        0.00     0.000000     0.000000         0.04
# 16    0.034545        0.00     0.043333     0.000000         0.00
# 17    0.046061        0.00     0.000000     0.000000         0.04
# 18    0.143939        0.00     0.043333     0.000000         0.00
# 19    0.166970        0.00     0.130000     0.000000         0.00
# 20    0.097879        0.00     0.086667     0.000000         0.00
# 21    0.190000        0.00     0.000000     0.000000         0.00
# 22    0.132424        0.00     0.130000     0.000000         0.00
# 23    0.143939        0.00     0.086667     0.000000         0.00
# 24    0.000000        0.00     0.043333     0.000000         0.00
# 25    0.000000        0.00     0.130000     0.000000         0.00
# 26    0.000000        0.00     0.086667     0.000000         0.00
# 27    0.000000        0.00     0.000000     0.066667         0.04
# 28    0.000000        0.00     0.130000     0.000000         0.00
# 29    0.000000        0.00     0.086667     0.000000         0.00
# 30    0.011515        0.17     0.000000     0.000000         0.04
# 31    0.034545        0.00     0.000000     0.000000         0.00
# 32    0.000000        0.17     0.000000     0.000000         0.00
# 33    0.000000        0.17     0.000000     0.066667         0.08
# 34    0.057576        0.17     0.000000     0.000000         0.04
# 35    0.011515        0.00     0.000000     0.000000         0.04
# 36    0.000000        0.17     0.000000     0.000000         0.00
# 37    0.023030        0.00     0.043333     0.033333         0.00
# 38    0.000000        0.17     0.000000     0.033333         0.00
# 39    0.000000        0.17     0.000000     0.100000         0.04
# 40    0.046061        0.17     0.000000     0.033333         0.00
# 41    0.000000        0.00     0.043333     0.033333         0.00

# %%
def sum_of_rows(df):
    l=[]
    df_n = df.copy()
    for i in range(df_n.shape[0]):
        l.append(sum(df_n.loc[i,]))
    df_n['Weighted'] = l
    return df_n

# %%
weighted_mat = aggregate_mat.copy()
weighted_mat = sum_of_rows(aggregate_mat.iloc[:,1:])

# %%
list_ = weighted_mat['Weighted']

# %% [markdown]
# # Step 4 : Forming Aggregated Matrix

# %%
def new_agg_mat_fun(df,list_,n):
    k=0
    new_agg_mat = df.copy()
    for i in range(n+1):
        for j in range(n+1):
            if i !=j:
                new_agg_mat.iloc[i,j] = list_[k]
                k+=1;
            else:
                new_agg_mat.iloc[i,j] = 0
    return new_agg_mat

# %%
new_agg_mat = new_agg_mat_fun(norm_matrix,list_,6)
new_agg_mat
# Out:
#    Output (per sq. meter)  Cost (per sq. meter)  Durability  Efficiency  \
# 0                0.000000              0.143057    0.183243    0.140000
# 1                0.231315              0.000000    0.297892    0.316667
# 2                0.086394              0.112784    0.000000    0.146667
# 3                0.280409              0.368817    0.383925    0.000000
# 4                0.053991              0.130027    0.203901    0.106667
# 5                0.221515              0.034572    0.170000    0.316667
# 6                0.170000              0.099724    0.281490    0.310000
#
#    Sensitivity  Maintenance  Scalability
# 0     0.079394     0.356837     0.071754
# 1     0.243688     0.258153     0.089736
# 2     0.132455     0.208473     0.086394
# 3     0.272478     0.592398     0.352163
# 4     0.000000     0.377495     0.125745
# 5     0.267576     0.000000     0.051515
# 6     0.249394     0.285084     0.000000

# %% [markdown]
# # Step 5 : calculating leaving and entering variables

# %%
def leaving_flow(df):
    df_n = df.copy()
    l=[]
    for i in range(df.shape[0]):
        l.append(round(sum(df_n.loc[i,])/len(df_n.loc[i,]),4))
    return l

# %%
def entering_flow(df):
    df_n = df.copy()
    l=[]
    for col in df_n.columns:
        l.append(round(sum(df[col])/df_n.shape[0],4))
    return l

# %%
def outrank():
    out_rank_df   = pd.DataFrame()
    out_rank_df['leaving_flow'] =  leaving_flow(new_agg_mat)
    out_rank_df['entering_flow'] = entering_flow(new_agg_mat)
    return out_rank_df

# %%
rank_mat = outrank()
rank_mat['Difference'] = rank_mat['leaving_flow']-rank_mat['entering_flow']

# %%
for col in df.columns:
    df.rename(columns = {col:col.strip()},inplace=True)

# %%
rank_mat['ranks'] = rank_mat['Difference'].rank(ascending=False).astype(int)
rank_mat['Material'] = df['Material']

# %%
# reordering
rank_mat = rank_mat[['Material','leaving_flow','entering_flow','Difference','ranks']]
rank_mat
# Out:
#                    Material  leaving_flow  entering_flow  Difference  ranks
# 0   Piezoelectric                  0.1392         0.1491     -0.0099      4
# 1   Triboelectric                  0.2054         0.1270      0.0784      3
# 2   Thermoelectric                 0.1105         0.2172     -0.1067      6
# 3   Photovoltaic                   0.3215         0.1910      0.1305      1
# 4   Electroactive Polymers         0.1425         0.1779     -0.0354      5
# 5   Magnetoelectric                0.1517         0.2969     -0.1452      7
# 6   Pyroelectric                   0.1994         0.1110      0.0884      2

# %% [markdown]
# # Promethee 1

# %%
def leaving_flow_pr1(df):
    df_n = df.copy()
    l=[]
    for i in range(df.shape[0]):
        l.append(round(sum(df_n.loc[i,]),4))
    return l

# %%
def entering_flow_pr1(df):
    df_n = df.copy()
    l=[]
    for col in df_n.columns:
        l.append(round(sum(df[col]),4))
    return l

# %%
def outrank_pr1():
    out_rank_df   = pd.DataFrame()
    out_rank_df['leaving_flow'] =  leaving_flow_pr1(new_agg_mat)
    out_rank_df['entering_flow'] = entering_flow_pr1(new_agg_mat)
    return out_rank_df

# %%
rank_mat_pr1 = outrank_pr1()

# %%
rank_mat_pr1
# Out:
#    leaving_flow  entering_flow
# 0        0.9743         1.0436
# 1        1.4375         0.8890
# 2        0.7732         1.5205
# 3        2.2502         1.3367
# 4        0.9978         1.2450
# 5        1.0618         2.0784
# 6        1.3957         0.7773
